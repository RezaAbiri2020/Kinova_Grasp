# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import pandas as pd
import math
import pickle

# %%
open_file = open('/media/reza/ResearchDrive/RealSenseCamera/VirtualCameraData/20210505/Obj1_ReplayKins_4.pkl', 'rb')
DataImages = pickle.load(open_file)

# %%
image1 = DataImages[0]

# %%
RGBA1 = image1[0]

# %%
RGBA1.shape
# Out:
# (720, 960, 4)

# %%
RGB1 = RGBA1[:,:,:3]

# %%
RGB1.shape
# Out:
# (720, 960, 3)

# %%
plt.imshow(RGB1)

# %%
i = 150
image = DataImages[i]
RGBA = image[0]
RGB = RGBA[:,:,:3]
plt.imshow(RGB)

# %%
i = 0
image = DataImages[i]
RGBA = image[0]
depth = RGBA[:,:,3]
depth
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
import seaborn as sns

# %%
sns.heatmap(depth)
# Out:
# <AxesSubplot:>
